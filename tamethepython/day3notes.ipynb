# %%
# reverse given list
alist=[123,'xyz','tommy']
print(alist)
alist.reverse()

print("reverse...")
print(alist)

# %%
# sort ascending or descending
blist = [8,99, 45, 33]

blist.sort()
print(blist)

blist.sort(reverse=True)
print (blist)

# %%
#alternative way to sort list
blist = [5,3,7,8,55,75]
sortedlist = sorted(blist)
print(sortedlist)
# Out:
# [3, 5, 7, 8, 55, 75]

# %%
print(alist.count("lusi"))
