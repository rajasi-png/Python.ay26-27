# %%
#convert tuples to list and list to tuples
x = ("apple", "banana", "cherry","k")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry', 'k')

# %%
##problem statement classwork consists of add update delete tuple assignment2
tuple1=("rajasi","aarnavi","ritvik")
#add
listbanao=list(tuple1)
listbanao.append("evan")
listbanao.insert(1, "aarav")
listbanao.remove("ritvik")
tuple1=tuple(listbanao)

print(tuple1)


dictio1={
  "name": "Remira Kiramman",
  "nickname": "Rem",
  "yearofbirth": 2008
}
#add items
dictio1["height"]= "6'2""

list1=[]
# Out:
# ('rajasi', 'aarav', 'aarnavi', 'evan')
